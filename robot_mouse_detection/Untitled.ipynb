# %%
import re

from util_funcs import *

# %load_ext autoreload
# %autoreload 2

# %%
with open('data/dsjtzs_txfz_training_sample.txt', 'r') as f:
        lines = f.readlines()

# %%
parse_training_set(lines)
# Out:
# {1: {'is_human': True,
#   'target': [1420.5, 202.0],
#   'trace': [[353.0, 2607.0, 349.0],
#    [367.0, 2607.0, 376.0],
#    [388.0, 2620.0, 418.0],
#    [416.0, 2620.0, 442.0],
#    [500.0, 2620.0, 493.0],
#    [584.0, 2620.0, 547.0],
#    [675.0, 2620.0, 592.0],
#    [724.0, 2620.0, 643.0],
#    [780.0, 2620.0, 694.0],
#    [822.0, 2620.0, 742.0],
#    [850.0, 2633.0, 793.0],
#    [885.0, 2633.0, 844.0],
#    [934.0, 2633.0, 895.0],
#    [983.0, 2633.0, 946.0],
#    [1060.0, 2633.0, 1006.0],
#    [1144.0, 2633.0, 1063.0],
#    [1235.0, 2633.0, 1093.0],
#    [1284.0, 2633.0, 1144.0],
#    [1312.0, 2633.0, 1210.0],
#    [1326.0, 2633.0, 1243.0],
#    [1333.0, 2633.0, 1354.0],
#    [1354.0, 2633.0, 1408.0],
#    [1375.0, 2646.0, 1450.0],
#    [1452.0, 2659.0, 1492.0],
#    [1473.0, 2672.0, 1543.0],
#    [1480.0, 2672.0, 1954.0],
#    [1487.0, 2672.0, 2050.0],
#    [1494.0, 2672.0, 2233.0],
#    [1501.0, 2672.0, 2245.0],
#    [1515.0, 2672.0, 2293.0],
#    [1515.0, 2659.0, 2347.0],
# ...
